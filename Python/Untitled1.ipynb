# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the positive roots of A_2 root system
roots = np.array([
    [1, -1, 0],
    [0, 1, -1],
    [-1, 0, 1]
])

# Extract the first two coordinates of the roots
roots_2d = roots[:, :2]

# Plot the positive Weyl chamber
fig, ax = plt.subplots()
ax.scatter(roots_2d[:, 0], roots_2d[:, 1])

# Annotate the roots
for i, root in enumerate(roots_2d):
    ax.annotate(f'α{i+1}', (root[0]+0.1, root[1]+0.1), fontsize=12)

# Set the axis labels and title
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Positive Weyl Chamber of A_2 Root System')

# Customize the plot appearance
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position('zero')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.xlim(-2, 2)
plt.ylim(-2, 2)

plt.show()
