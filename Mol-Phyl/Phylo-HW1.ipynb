# %% [markdown]
# # Homework I.
# ## V. M. Smirnov

# %%
import requests 
import pylab 
from io import StringIO
from Bio import Phylo

import random
from ete3 import Tree, TreeStyle, NodeStyle
import matplotlib
import PyQt5
# !pip3 install PyQt5

# %% [markdown]
# ## Python: Bio::Phylo
# ### 11. Read the tree

# %%
raw_tree = StringIO(requests.get('https://www.jasondavies.com/tree-of-life/life.txt').text)

# %% [markdown]
# ### 12. Draw the tree using ASCII

# %%
tree1 = Phylo.read(raw_tree, "newick")
Phylo.draw_ascii(tree1)
# Out:
#                              , Escherichia_coli_EDL933
#                              |
#                              | Escherichia_coli_O157_H7
#                              |
#                              , Escherichia_coli_O6
#                              |
#                              | Escherichia_coli_K12
#                              |
#                              , Shigella_flexneri_2a_2457T
#                              |
#                              | Shigella_flexneri_2a_301
#                              |
#                              , Salmonella_enterica
#                              |
#                              | Salmonella_typhi
#                              |
#                              | Salmonella_typhimurium
#                              |
#                              , Yersinia_pestis_Medievalis
#                              |
#                              , Yersinia_pestis_KIM
#                              |
# ...

# %% [markdown]
# ### 13. Draw the tree using .draw

# %%
matplotlib.rc('font', size=1) # change the size of the labels
Phylo.draw(tree1, do_show=True)

# %% [markdown]
# ### 14. Save the picture to .png and .svg

# %%
Phylo.draw(tree1, do_show=False)
matplotlib.pyplot.savefig("py_tree_1_phylo.svg")
matplotlib.pyplot.savefig("py_tree_1_phylo.png")

# %% [markdown]
# ### 15. Make the tree look better

# %%
## Impossible

# %% [markdown]
# ## Python: ETE3
#
# ### 16. Read the tree

# %%
raw_tree = requests.get('https://www.jasondavies.com/tree-of-life/life.txt').text
tree2 = Tree(raw_tree, format=1)

# %% [markdown]
# ### 17. Draw the tree

# %%
tree2.render("py_tree2_ete3.pdf")
tree2.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 18. Draw the tree, but with style

# %%
circular_style = TreeStyle()
circular_style.mode = "c"
circular_style.scale = 20
tree2.show(tree_style=circular_style)
tree2.render("py_tree2_ete3_circ.pdf", tree_style=circular_style)
# Out:
# {'nodes': [[689.4852572785558,
#    688.3779019700625,
#    694.3102029907212,
#    693.2028476822279,
#    0,
#    None],
#   [658.4659787075122,
#    685.4141985831113,
#    662.9984111568856,
#    689.9466310324847,
#    1,
#    None],
#   [659.2450812296644,
#    707.8958131853178,
#    664.7409694223252,
#    713.3917013779786,
#    2,
#    None],
#   [671.1348717747175,
#    724.0766328174343,
#    676.5462737075567,
#    729.4880347502735,
#    3,
#    None],
#   [677.8236042972975,
#    731.3625666687874,
#    682.7727395610544,
#    736.3117019325443,
#    4,
#    None],
#   [685.7182522127789,
#    737.0534084261401,
#    690.0703407743076,
#    741.4054969876688,
#    5,
#    None],
#   [697.6186194960202,
#    740.8682705732379,
#    702.1684128318274,
#    745.418063909045,
#    6,
#    None],
#   [712.2396559527859,
#    742.8942152172236,
#    717.4846846882725,
#    748.1392439527102,
#    7,
#    None],
#   [721.4307005233002,
#    742.1263635791356,
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 19. Prune a random set of 42 leaves

# %%
ss = random.sample(tree2.get_leaf_names(), 42)
tree2.prune(ss)
tree2.show(tree_style=circular_style)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 20. Draw the truncated tree
# See above

# %% [markdown]
# ### 21. More style

# %%
ts = TreeStyle()
ts.branch_vertical_margin = 15

nstyle = NodeStyle()
nstyle["shape"] = "square"
nstyle["size"] = 5 
nstyle["fgcolor"] = "lightblue"
for leaf in tree2.traverse(): 
   leaf.set_style(nstyle)

tree2.show(tree_style=ts)

# %% [markdown]
# ![image.png](attachment:image.png)
